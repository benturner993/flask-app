# %%
import pandas as pd

# %%
df=pd.read_csv('reactive_input.csv')
df.head(3)
# Out:
#    CustomerID           Name                     Email         Phone  \
# 0           1       John Doe       johndoe@example.com  123-456-7890
# 1           2     Jane Smith     janesmith@example.com  987-654-3210
# 2           3  Alice Johnson  alicejohnson@example.com  456-789-0123
#
#    Lapse_Propensity  Customer_Lifetime_Value Call_Agent Discount_Eligibility  \
# 0              0.25                     1500    Agent A             eligible
# 1              0.35                     1200    Agent B             eligible
# 2              0.15                      800    Agent C         not eligible
#
#    Annual_Premium
# 0            1000
# 1            1100
# 2            1050

# %%
from faker import Faker
import random
import pandas as pd

# Initialize Faker
fake = Faker()

def generate_customer():
    name = fake.name()
    email = fake.email()
    phone_number = fake.phone_number()
    
    # Generate Lapse_Propensity
    lapse_propensity = round(random.random(), 2)
    
    # Adjust Month propensities based on Lapse_Propensity
    if lapse_propensity > 0.5:
        month_1_propensity = round(random.uniform(0, 0.5), 2)
        month_2_propensity = round(random.uniform(0, 0.5), 2)
        month_3_propensity = round(random.uniform(0, 0.5), 2)
    else:
        month_1_propensity = round(random.uniform(0.5, 1), 2)
        month_2_propensity = round(random.uniform(0.5, 1), 2)
        month_3_propensity = round(random.uniform(0.5, 1), 2)
    
    # Set Discount_Eligibility to "eligible" 80% of the time
    discount_eligibility = random.choices(['eligible', 'not eligible'], weights=[0.8, 0.2])[0]
    
    return {
        'Name': name,
        'Email': email,
        'Phone': phone_number,
        'Lapse_Propensity': lapse_propensity,
        'Customer_Lifetime_Value': round(random.uniform(-5000, 50000), 2),
        'Call_Agent': name,
        'Discount_Eligibility': discount_eligibility,
        'Age': random.randint(18, 70),
        'Tenure': random.randint(1, 20),
        'Family_Status': random.choice(['Single', 'Couple', 'Single parent family', 'Family', 'Family with Multiple Children']),
        'Annual_Premium': round(random.uniform(1000, 10000), 2),
        'Month_1_Free_Propensity': month_1_propensity,
        'Month_2_Free_Propensity': month_2_propensity,
        'Month_3_Free_Propensity': month_3_propensity,
    }

# Generate 50 random customers
customer_data = [generate_customer() for _ in range(50)]

# Assign CustomerID sequentially from 1 to 50
for index, customer in enumerate(customer_data, start=1):
    customer['CustomerID'] = index
    
# Convert the list of dictionaries to a DataFrame
df_customers = pd.DataFrame(customer_data)

# export
df_customers.to_csv('reactive_input_2.csv', index=False)

# %%
df_customers
# Out:
#                        Name                         Email  \
# 0            Rebecca Bright     candacewilson@example.org
# 1            Tiffany Barnes      daniellelove@example.org
# 2          Virginia Flowers     hoffmanandrew@example.com
# 3             Shane Jackson           susan74@example.org
# 4              Albert Lewis      josephnewton@example.org
# 5              Toni Maxwell         richard59@example.net
# 6                John Stout          joshua98@example.net
# 7       Christopher Gilmore     patriciawhite@example.com
# 8              Laura Bolton          kurtreed@example.org
# 9              Amanda Smith         qmarshall@example.net
# 10              David Lewis          andrea74@example.org
# 11              Deanna Wood    patriciaduncan@example.org
# 12          Adam Galvan Jr.       garciapeter@example.net
# 13          Nicholas Baxter             qhill@example.org
# 14         Danielle Pacheco            ahobbs@example.net
# ...
